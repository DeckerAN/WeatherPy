# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * From the sample, cities up to -40 degrees Lat seem to be more humid than cities up to +40 degrees Lat.
# * Cities look to be less windy when they are nearest to the equator (0 Lat).
# * From the sample on the date collected, the hottest cities tend to lie just north of the equator (within +20 degrees Lat).

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy.core as owm
from datetime import datetime

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_csv = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90.000, 90.000)
lng_range = (-180.000, 180.000)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
rnd_size = 2000

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=lat_range[0], high=lat_range[1], size=rnd_size)
lngs = np.random.uniform(low=lng_range[0], high=lng_range[1], size=rnd_size)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 756

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Fields for the OMW api
settings = {'units': 'metric', 'appid': api_key}

# Empty lists that will store relevant city weather info
city_ls = []
country_ls = []
lat_ls = []
lng_ls = []
date_ls = []
humidity_ls = []
cloudy_ls = []
max_temp_c_ls = []
wind_ls = []

# Iterating through all randomly-generated cities for weather data using wrapper
print(f"""Beginning Data Retrieval
--------------------------------""")
counter = 0
for city in cities:
    try:
        current_weather = owm.get_current(city, **settings)
        counter += 1
            # Printing process log
        print(f"Processing Record {counter} | {current_weather['name']}, {current_weather['sys']['country']}")
            # Adding city info to lists to eventually add to DF below
        city_ls.append(current_weather['name'])
        country_ls.append(current_weather['sys']['country'])
        lat_ls.append(current_weather['coord']['lat'])
        lng_ls.append(current_weather['coord']['lon'])
        date_ls.append(current_weather['dt'])
        humidity_ls.append(current_weather['main']['humidity'])
        cloudy_ls.append(current_weather['clouds']['all'])
        max_temp_c_ls.append(current_weather['main']['temp_max'])
        wind_ls.append(current_weather['wind']['speed'])
    except:
        print('City not found. Skipping...')
        
print(f"""--------------------------------
Data Retrieval Complete
--------------------------------""")
# Out:
# Beginning Data Retrieval
# --------------------------------
# City not found. Skipping...
# Processing Record 1 | Nikolskoye, RU
# Processing Record 2 | Saint-Philippe, CA
# Processing Record 3 | Saiha, IN
# Processing Record 4 | Fatehabad, IN
# Processing Record 5 | Talnakh, RU
# Processing Record 6 | Hermanus, ZA
# Processing Record 7 | Jashpurnagar, IN
# Processing Record 8 | Kavieng, PG
# Processing Record 9 | Eureka, US
# Processing Record 10 | Vao, EE
# Processing Record 11 | Pisco, PE
# Processing Record 12 | Bauchi, NG
# Processing Record 13 | Arraial do Cabo, BR
# Processing Record 14 | Novyy Urengoy, RU
# Processing Record 15 | Cabo San Lucas, MX
# Processing Record 16 | Lewistown, US
# Processing Record 17 | Esperance, TT
# City not found. Skipping...
# Processing Record 18 | Iqaluit, CA
# Processing Record 19 | Pundaguitan, PH
# Processing Record 20 | Rikitea, PF
# Processing Record 21 | Rio Tercero, AR
# Processing Record 22 | Bluff, AU
# Processing Record 23 | Tuktoyaktuk, CA
# Processing Record 24 | Chokurdakh, RU
# Processing Record 25 | Ushuaia, AR
# Processing Record 26 | Lebu, ET
# Processing Record 27 | Thompson, CA
# Processing Record 28 | Baykit, RU
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 29 | Krasnyy Chikoy, RU
# Processing Record 30 | Butaritari, KI
# Processing Record 31 | Diego de Almagro, CL
# Processing Record 32 | Husavik, CA
# Processing Record 33 | Hithadhoo, MV
# Processing Record 34 | Kapaa, US
# Processing Record 35 | Mitsamiouli, KM
# Processing Record 36 | New Norfolk, AU
# Processing Record 37 | Bulgan, MN
# Processing Record 38 | Inuvik, CA
# Processing Record 39 | Cariati, IT
# Processing Record 40 | Jamestown, AU
# City not found. Skipping...
# Processing Record 41 | Aklavik, CA
# Processing Record 42 | Mehamn, NO
# Processing Record 43 | Port Lincoln, AU
# City not found. Skipping...
# Processing Record 44 | Ponta do Sol, BR
# Processing Record 45 | Laje, BR
# Processing Record 46 | Georgetown, GY
# Processing Record 47 | Port Macquarie, AU
# City not found. Skipping...
# Processing Record 48 | Albany, US
# Processing Record 49 | Sao Filipe, CV
# Processing Record 50 | Salzhemmendorf, DE
# Processing Record 51 | Raahe, FI
# Processing Record 52 | Tura, IN
# Processing Record 53 | Vaini, IN
# Processing Record 54 | Bredasdorp, ZA
# Processing Record 55 | Alice Springs, AU
# Processing Record 56 | Pucallpa, PE
# Processing Record 57 | Cape Town, ZA
# Processing Record 58 | Tshikapa, CD
# Processing Record 59 | Puerto Ayora, EC
# Processing Record 60 | Latung, ID
# Processing Record 61 | Lorengau, PG
# City not found. Skipping...
# Processing Record 62 | Port Alfred, ZA
# Processing Record 63 | Ciudad Bolivar, VE
# Processing Record 64 | Qaanaaq, GL
# Processing Record 65 | Torbay, CA
# Processing Record 66 | Beyla, GN
# Processing Record 67 | Touros, BR
# Processing Record 68 | Kahului, US
# Processing Record 69 | Mataura, NZ
# Processing Record 70 | Sesheke, NA
# Processing Record 71 | Cidreira, BR
# City not found. Skipping...
# Processing Record 72 | Atherton, GB
# Processing Record 73 | Surab, PK
# Processing Record 74 | Castro, CL
# Processing Record 75 | Sao Joao da Ponte, BR
# Processing Record 76 | Constitucion, MX
# Processing Record 77 | Hobart, AU
# Processing Record 78 | Camopi, GF
# Processing Record 79 | Antanifotsy, MG
# Processing Record 80 | Namibe, AO
# Processing Record 81 | Ancud, CL
# City not found. Skipping...
# Processing Record 82 | Cananea, MX
# Processing Record 83 | Harrison, US
# Processing Record 84 | Hilo, US
# City not found. Skipping...
# Processing Record 85 | Namatanai, PG
# Processing Record 86 | Kodiak, US
# Processing Record 87 | Tapiramuta, BR
# Processing Record 88 | Provideniya, RU
# City not found. Skipping...
# Processing Record 89 | Necochea, AR
# City not found. Skipping...
# Processing Record 90 | Nichinan, JP
# City not found. Skipping...
# Processing Record 91 | Kulhudhuffushi, MV
# Processing Record 92 | Vila Franca do Campo, PT
# Processing Record 93 | Lagoa, PT
# Processing Record 94 | Punta Arenas, CL
# Processing Record 95 | Ca Mau, VN
# Processing Record 96 | Damara, CF
# City not found. Skipping...
# Processing Record 97 | Chuy, UY
# Processing Record 98 | Portland, US
# Processing Record 99 | North Battleford, CA
# Processing Record 100 | Chipinge, ZW
# Processing Record 101 | Atar, MR
# Processing Record 102 | Aginskoye, RU
# Processing Record 103 | Russell, AR
# Processing Record 104 | Soke, ML
# Processing Record 105 | Sovetskiy, RU
# Processing Record 106 | Ewa Beach, US
# Processing Record 107 | Berlevag, NO
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 108 | Eufaula, US
# Processing Record 109 | Nyurba, RU
# City not found. Skipping...
# Processing Record 110 | Muisne, EC
# Processing Record 111 | Pacific Grove, US
# Processing Record 112 | Nikolayevsk-na-amure, RU
# Processing Record 113 | Rumoi, JP
# City not found. Skipping...
# Processing Record 114 | Busselton, AU
# Processing Record 115 | Huntsville, US
# Processing Record 116 | Kota, IN
# Processing Record 117 | Ilmatsalu, EE
# Processing Record 118 | Roros, NO
# City not found. Skipping...
# Processing Record 119 | Tiksi, RU
# Processing Record 120 | Praia, BR
# Processing Record 121 | Severo-Kurilsk, RU
# Processing Record 122 | Bedesa, ET
# Processing Record 123 | Sarankhola, BD
# Processing Record 124 | Atuona, PF
# Processing Record 125 | East London, ZA
# Processing Record 126 | Tabuk, PH
# Processing Record 127 | Havoysund, NO
# Processing Record 128 | Saint-Pierre, FR
# Processing Record 129 | Ketchikan, US
# Processing Record 130 | Camacha, PT
# Processing Record 131 | San Patricio, PY
# City not found. Skipping...
# Processing Record 132 | Madison, US
# Processing Record 133 | Dingle, PH
# Processing Record 134 | Dikson, RU
# Processing Record 135 | Klaksvik, FO
# Processing Record 136 | Grindavik, IS
# Processing Record 137 | Hasaki, JP
# City not found. Skipping...
# Processing Record 138 | Nizwa, OM
# Processing Record 139 | Dongsheng, CN
# Processing Record 140 | Samsun, TR
# Processing Record 141 | Alcudia, ES
# Processing Record 142 | Bambous Virieux, MU
# Processing Record 143 | Sena Madureira, BR
# Processing Record 144 | Mount Gambier, AU
# Processing Record 145 | Yellowknife, CA
# Processing Record 146 | Victoria, BN
# Processing Record 147 | Xining, CN
# Processing Record 148 | Bodden Town, KY
# Processing Record 149 | Colonial Heights, US
# Processing Record 150 | Eyl, SO
# Processing Record 151 | Am Timan, TD
# Processing Record 152 | Nishihara, JP
# City not found. Skipping...
# Processing Record 153 | Hokitika, NZ
# Processing Record 154 | Beringovskiy, RU
# Processing Record 155 | Avarua, CK
# Processing Record 156 | Sur, OM
# Processing Record 157 | Kruisfontein, ZA
# Processing Record 158 | Novobirilyussy, RU
# Processing Record 159 | Poum, MK
# City not found. Skipping...
# Processing Record 160 | Sobolevo, RU
# Processing Record 161 | Airai, TL
# Processing Record 162 | Gasa, BT
# City not found. Skipping...
# Processing Record 163 | Marzuq, YE
# Processing Record 164 | Tottori, JP
# Processing Record 165 | Vila Velha, BR
# Processing Record 166 | Ornskoldsvik, SE
# City not found. Skipping...
# Processing Record 167 | Koumac, NC
# Processing Record 168 | Khatanga, RU
# Processing Record 169 | Topolobampo, MX
# Processing Record 170 | Ribeira Grande, PT
# Processing Record 171 | Grand Gaube, MU
# Processing Record 172 | Maine-Soroa, NE
# Processing Record 173 | Pevek, RU
# Processing Record 174 | Upernavik, GL
# Processing Record 175 | Iraucuba, BR
# Processing Record 176 | Cherskiy, RU
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 177 | Faanui, PF
# Processing Record 178 | Barrow, AR
# Processing Record 179 | Nantucket, US
# Processing Record 180 | Mount Isa, AU
# Processing Record 181 | Riyadh, SA
# Processing Record 182 | Ust-Kulom, RU
# Processing Record 183 | Shiyan, CN
# Processing Record 184 | Lianran, CN
# Processing Record 185 | Srednekolymsk, RU
# Processing Record 186 | Sitka, US
# Processing Record 187 | Phibun Mangsahan, TH
# Processing Record 188 | Saint-Joseph, FR
# Processing Record 189 | Jiayuguan, CN
# Processing Record 190 | Laguna, MX
# Processing Record 191 | Araceli, PH
# Processing Record 192 | Tuim, RU
# Processing Record 193 | Nome, US
# Processing Record 194 | Kitimat, CA
# Processing Record 195 | Batemans Bay, AU
# Processing Record 196 | Sao Joao da Barra, BR
# Processing Record 197 | Leningradskiy, RU
# Processing Record 198 | Jose de Freitas, BR
# Processing Record 199 | Port Hedland, AU
# Processing Record 200 | Alofi, NU
# Processing Record 201 | Tasiilaq, GL
# Processing Record 202 | Bonthe, SL
# Processing Record 203 | Longyearbyen, NO
# Processing Record 204 | Port Blair, IN
# Processing Record 205 | Chake Chake, TZ
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 206 | Aykhal, RU
# Processing Record 207 | Palana, RU
# Processing Record 208 | Kita, JP
# Processing Record 209 | Bambui, CM
# Processing Record 210 | San Jose del Guaviare, CO
# Processing Record 211 | Tymovskoye, RU
# Processing Record 212 | Hibbing, US
# Processing Record 213 | Lloydminster, CA
# City not found. Skipping...
# Processing Record 214 | Chilca, PE
# Processing Record 215 | Buraydah, SA
# Processing Record 216 | Alamosa, US
# Processing Record 217 | Cayenne, GF
# Processing Record 218 | Cabadiangan, PH
# Processing Record 219 | Voyvozh, RU
# Processing Record 220 | Tautira, PF
# Processing Record 221 | Mar del Plata, AR
# Processing Record 222 | Halifax, CA
# Processing Record 223 | Seoul, KR
# Processing Record 224 | Salinopolis, BR
# Processing Record 225 | Mahebourg, MU
# Processing Record 226 | Tallahassee, US
# Processing Record 227 | Chiang Mai, TH
# City not found. Skipping...
# Processing Record 228 | Trincomalee, LK
# Processing Record 229 | Itarema, BR
# Processing Record 230 | Takoradi, GH
# Processing Record 231 | Bethel, US
# Processing Record 232 | Cabedelo, BR
# Processing Record 233 | Ilulissat, GL
# Processing Record 234 | Acapulco, MX
# Processing Record 235 | Quesnel, CA
# Processing Record 236 | Henties Bay, NA
# Processing Record 237 | Vilhena, BR
# Processing Record 238 | Port Elizabeth, US
# Processing Record 239 | Lat Yao, TH
# Processing Record 240 | Vung Tau, VN
# Processing Record 241 | Villarrica, CL
# Processing Record 242 | Viedma, AR
# City not found. Skipping...
# Processing Record 243 | Kenai, US
# Processing Record 244 | Norman Wells, CA
# Processing Record 245 | Evans, US
# Processing Record 246 | Kloulklubed, PW
# Processing Record 247 | Kavaratti, IN
# Processing Record 248 | Ostrovnoy, RU
# Processing Record 249 | Penzance, GB
# Processing Record 250 | Mvuma, ZW
# Processing Record 251 | Komsomolskiy, RU
# City not found. Skipping...
# Processing Record 252 | Enshi, CN
# Processing Record 253 | Soyo, AO
# Processing Record 254 | Abalak, NE
# Processing Record 255 | Bundaberg, AU
# Processing Record 256 | Khasan, RU
# Processing Record 257 | Langham, CA
# Processing Record 258 | Sawakin, SD
# City not found. Skipping...
# Processing Record 259 | Coihaique, CL
# Processing Record 260 | Abha, SA
# Processing Record 261 | Lata, IN
# Processing Record 262 | Zyryanka, RU
# Processing Record 263 | Deputatskiy, RU
# City not found. Skipping...
# Processing Record 264 | San Vicente, SV
# Processing Record 265 | Nyagan, RU
# Processing Record 266 | Geraldton, CA
# Processing Record 267 | Gerash, IR
# Processing Record 268 | Safita, SY
# City not found. Skipping...
# Processing Record 269 | Bitam, GA
# Processing Record 270 | Zhuhai, CN
# Processing Record 271 | Smirnykh, RU
# Processing Record 272 | Preobrazheniye, RU
# Processing Record 273 | Mogadishu, SO
# Processing Record 274 | Rocha, UY
# Processing Record 275 | Vanavara, RU
# Processing Record 276 | Qingdao, CN
# Processing Record 277 | Kilembe, UG
# Processing Record 278 | Libertador General San Martin, AR
# Processing Record 279 | Nemuro, JP
# Processing Record 280 | Kaitangata, NZ
# Processing Record 281 | Antsohihy, MG
# Processing Record 282 | Codrington, AU
# Processing Record 283 | Saskylakh, RU
# Processing Record 284 | Inongo, CD
# City not found. Skipping...
# Processing Record 285 | Westport, IE
# Processing Record 286 | Belyy Yar, RU
# Processing Record 287 | San Ignacio, CL
# City not found. Skipping...
# Processing Record 288 | Soe, EE
# Processing Record 289 | Harnosand, SE
# City not found. Skipping...
# Processing Record 290 | Shingu, JP
# Processing Record 291 | Lasa, CY
# Processing Record 292 | Kalemie, CD
# City not found. Skipping...
# Processing Record 293 | Pano Aqil, PK
# Processing Record 294 | Donskoye, RU
# Processing Record 295 | Fortuna, ES
# Processing Record 296 | Qianan, CN
# Processing Record 297 | Carutapera, BR
# Processing Record 298 | Sorong, ID
# Processing Record 299 | Piacabucu, BR
# Processing Record 300 | Saint Lawrence, MT
# Processing Record 301 | Guia de Isora, ES
# Processing Record 302 | Fujin, CN
# Processing Record 303 | Hambantota, LK
# Processing Record 304 | Sturgeon Falls, CA
# Processing Record 305 | Zabid, YE
# Processing Record 306 | Saint-Francois, FR
# Processing Record 307 | Subang, MY
# City not found. Skipping...
# Processing Record 308 | Wilmington, US
# Processing Record 309 | Maryborough, AU
# City not found. Skipping...
# Processing Record 310 | Te Anau, NZ
# Processing Record 311 | Venado Tuerto, AR
# Processing Record 312 | Mareeba, AU
# Processing Record 313 | Verkhoyansk, RU
# Processing Record 314 | Northam, GB
# Processing Record 315 | Santa Isabel do Rio Negro, BR
# Processing Record 316 | Saint Anthony, US
# Processing Record 317 | Ludhiana, IN
# Processing Record 318 | Tuatapere, NZ
# Processing Record 319 | Carnarvon, ZA
# Processing Record 320 | Simbahan, PH
# City not found. Skipping...
# Processing Record 321 | Tabou, CI
# Processing Record 322 | Mayo, CA
# Processing Record 323 | Hofn, IS
# Processing Record 324 | Takahagi, JP
# Processing Record 325 | Saint-Georges, CA
# Processing Record 326 | Sioux Lookout, CA
# Processing Record 327 | Manzanillo, CU
# Processing Record 328 | Barrhead, CA
# Processing Record 329 | Kosh-Agach, RU
# Processing Record 330 | Lazaro Cardenas, MX
# Processing Record 331 | Kushima, JP
# Processing Record 332 | Arlit, NE
# Processing Record 333 | Ilam, IR
# Processing Record 334 | Isangel, VU
# City not found. Skipping...
# Processing Record 335 | Tarauaca, BR
# Processing Record 336 | Ojinaga, US
# Processing Record 337 | Omsukchan, RU
# Processing Record 338 | Narrabri, AU
# Processing Record 339 | Matamoros, US
# City not found. Skipping...
# Processing Record 340 | Great Falls, US
# Processing Record 341 | Inhambane, MZ
# Processing Record 342 | Souillac, FR
# Processing Record 343 | Taoudenni, ML
# Processing Record 344 | Poso, ID
# Processing Record 345 | Barahona, DO
# Processing Record 346 | Turukhansk, RU
# Processing Record 347 | Hamilton, BM
# Processing Record 348 | Saint George, GR
# Processing Record 349 | Tezu, IN
# Processing Record 350 | Antofagasta, CL
# Processing Record 351 | Otane, NZ
# Processing Record 352 | Hesperia, US
# Processing Record 353 | Roald, NO
# Processing Record 354 | Bagdarin, RU
# Processing Record 355 | Campeche, MX
# City not found. Skipping...
# Processing Record 356 | Bolshaya Glushitsa, RU
# Processing Record 357 | Mezen, RU
# Processing Record 358 | Clyde River, CA
# Processing Record 359 | Panama City, US
# Processing Record 360 | Mecca, SA
# Processing Record 361 | Tongzi, CN
# Processing Record 362 | Dunedin, NZ
# Processing Record 363 | Zaysan, KZ
# Processing Record 364 | Kindu, CD
# Processing Record 365 | Bathsheba, BB
# Processing Record 366 | Carnot, CF
# Processing Record 367 | Belawan, ID
# Processing Record 368 | Athabasca, CA
# Processing Record 369 | Vestmannaeyjar, IS
# Processing Record 370 | Morros, BR
# Processing Record 371 | Myitkyina, MM
# Processing Record 372 | Mujiayingzi, CN
# Processing Record 373 | Paamiut, GL
# City not found. Skipping...
# Processing Record 374 | Yamada, JP
# Processing Record 375 | Wajid, SO
# Processing Record 376 | Ventspils, LV
# Processing Record 377 | Monterey, US
# Processing Record 378 | Nanortalik, GL
# Processing Record 379 | El Alto, BO
# Processing Record 380 | Bella Union, CO
# Processing Record 381 | Litovko, RU
# Processing Record 382 | Waipawa, NZ
# Processing Record 383 | Grand Forks, US
# Processing Record 384 | Yulara, AU
# Processing Record 385 | Kaeo, NZ
# Processing Record 386 | Narsaq, GL
# Processing Record 387 | Sayyan, YE
# Processing Record 388 | Piritiba, BR
# Processing Record 389 | Thap Than, TH
# Processing Record 390 | Lufilufi, WS
# Processing Record 391 | Katsuura, JP
# Processing Record 392 | Larap, PH
# Processing Record 393 | Alihe, CN
# Processing Record 394 | Yanam, IN
# Processing Record 395 | Batagay, RU
# Processing Record 396 | Zhezkazgan, KZ
# Processing Record 397 | Arkansas City, US
# Processing Record 398 | Rudsar, IR
# Processing Record 399 | Basco, US
# Processing Record 400 | Labuhan, ID
# Processing Record 401 | Emerald, AU
# Processing Record 402 | Nacala, MZ
# City not found. Skipping...
# Processing Record 403 | Gonzalez, CO
# City not found. Skipping...
# Processing Record 404 | Somoto, NI
# Processing Record 405 | Lethem, GY
# Processing Record 406 | Shelburne, CA
# Processing Record 407 | Garden City, US
# Processing Record 408 | Kamenka, RU
# Processing Record 409 | Ibia, NG
# Processing Record 410 | Haines Junction, CA
# Processing Record 411 | Najran, SA
# Processing Record 412 | Ossora, RU
# Processing Record 413 | Jining, CN
# Processing Record 414 | San Quintin, PH
# Processing Record 415 | Tanda, IN
# Processing Record 416 | Kjollefjord, NO
# Processing Record 417 | Korocha, RU
# Processing Record 418 | Ahipara, NZ
# Processing Record 419 | Calvinia, ZA
# Processing Record 420 | Kontagora, NG
# Processing Record 421 | Qom, IR
# Processing Record 422 | Chillan, CL
# Processing Record 423 | Saldanha, PT
# Processing Record 424 | Sinnamary, GF
# Processing Record 425 | Sterling, US
# Processing Record 426 | Rio Grande, BR
# Processing Record 427 | Nikko, JP
# Processing Record 428 | Lompoc, US
# Processing Record 429 | Guerrero Negro, MX
# Processing Record 430 | Usinsk, RU
# Processing Record 431 | Filingue, NE
# Processing Record 432 | Vestmanna, FO
# Processing Record 433 | Pangnirtung, CA
# Processing Record 434 | Okha, RU
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 435 | Morehead, US
# Processing Record 436 | Caracuaro, MX
# Processing Record 437 | Gat, SN
# Processing Record 438 | Kidal, ML
# Processing Record 439 | Jacksonville, US
# Processing Record 440 | Gushikawa, JP
# Processing Record 441 | Salta, AR
# Processing Record 442 | Faya, SA
# Processing Record 443 | Jacareacanga, BR
# Processing Record 444 | Magole, TZ
# Processing Record 445 | Vitoria do Mearim, BR
# Processing Record 446 | Jadu, LY
# Processing Record 447 | Foumban, CM
# Processing Record 448 | Boffa, GN
# Processing Record 449 | Puerto Narino, CO
# Processing Record 450 | Show Low, US
# Processing Record 451 | Broken Hill, AU
# Processing Record 452 | Marsa Matruh, EG
# Processing Record 453 | Palora, EC
# Processing Record 454 | Erenhot, CN
# Processing Record 455 | Lamu, ID
# Processing Record 456 | Kwinana, AU
# Processing Record 457 | Maanshan, CN
# Processing Record 458 | Padang, ID
# Processing Record 459 | Tigil, RU
# Processing Record 460 | Los Llanos de Aridane, ES
# Processing Record 461 | Hovd, NO
# Processing Record 462 | Pipri, IN
# Processing Record 463 | Niquero, CU
# Processing Record 464 | Bonavista, CA
# Processing Record 465 | Staffanstorp, SE
# Processing Record 466 | Burnie, AU
# Processing Record 467 | Alekseyevsk, RU
# Processing Record 468 | Salalah, OM
# Processing Record 469 | Oktyabrskiy, RU
# Processing Record 470 | Chumikan, RU
# Processing Record 471 | Porgera, PG
# City not found. Skipping...
# Processing Record 472 | Piatra Soimului, RO
# City not found. Skipping...
# Processing Record 473 | Kailua, US
# Processing Record 474 | Antibes, FR
# Processing Record 475 | Smithers, CA
# Processing Record 476 | Troitskoye, RU
# Processing Record 477 | Ravar, IR
# Processing Record 478 | Moose Factory, CA
# Processing Record 479 | Aksu, KZ
# Processing Record 480 | Huilong, CN
# Processing Record 481 | Bereda, ES
# Processing Record 482 | Caravelas, BR
# Processing Record 483 | Broome, GB
# Processing Record 484 | Ponnani, IN
# Processing Record 485 | Port Hardy, CA
# City not found. Skipping...
# Processing Record 486 | Kon Tum, VN
# Processing Record 487 | Miyako, JP
# Processing Record 488 | College, US
# Processing Record 489 | Charters Towers, AU
# Processing Record 490 | Roebourne, AU
# Processing Record 491 | Kutum, SD
# Processing Record 492 | Balabac, PH
# Processing Record 493 | Brae, GB
# City not found. Skipping...
# Processing Record 494 | Timbuktu, ML
# Processing Record 495 | Ous, RU
# City not found. Skipping...
# Processing Record 496 | Kumano, JP
# Processing Record 497 | Zhigansk, RU
# Processing Record 498 | Asheville, US
# Processing Record 499 | Coolum Beach, AU
# Processing Record 500 | Jumla, NP
# Processing Record 501 | Parabel, RU
# Processing Record 502 | Celestun, MX
# City not found. Skipping...
# Processing Record 503 | Pathein, MM
# City not found. Skipping...
# Processing Record 504 | Lavrentiya, RU
# City not found. Skipping...
# Processing Record 505 | Sume, RS
# City not found. Skipping...
# Processing Record 506 | Boyolangu, ID
# Processing Record 507 | Santa Rosalia, IT
# Processing Record 508 | Ribas do Rio Pardo, BR
# Processing Record 509 | Nola, CF
# Processing Record 510 | Bowen, AU
# Processing Record 511 | Turayf, SA
# City not found. Skipping...
# Processing Record 512 | Tessalit, ML
# Processing Record 513 | Vilcun, CL
# Processing Record 514 | Esna, RO
# Processing Record 515 | Meulaboh, ID
# Processing Record 516 | Nyuksenitsa, RU
# Processing Record 517 | Tres Arroyos, AR
# Processing Record 518 | Severobaykalsk, RU
# Processing Record 519 | Araouane, ML
# Processing Record 520 | San Andres, PH
# Processing Record 521 | Jimma, ET
# Processing Record 522 | Margate, AU
# Processing Record 523 | Bheramara, BD
# Processing Record 524 | Nevers, FR
# Processing Record 525 | Nuuk, GL
# Processing Record 526 | Weihe, CN
# Processing Record 527 | Novo Aripuana, BR
# Processing Record 528 | Stodolishche, RU
# City not found. Skipping...
# Processing Record 529 | Charagua, BO
# City not found. Skipping...
# Processing Record 530 | Auki, NG
# Processing Record 531 | Bukachacha, RU
# Processing Record 532 | Creston, US
# Processing Record 533 | Menongue, AO
# Processing Record 534 | Yarada, IN
# Processing Record 535 | Santa Rosa de Aguan, HN
# Processing Record 536 | Flinders, AU
# Processing Record 537 | Emba, CY
# Processing Record 538 | Uige, AO
# Processing Record 539 | Huanren, CN
# City not found. Skipping...
# Processing Record 540 | Bubaque, GW
# Processing Record 541 | Egvekinot, RU
# Processing Record 542 | Mananjary, MG
# Processing Record 543 | Humberto de Campos, BR
# Processing Record 544 | Lima, PE
# Processing Record 545 | Ambanja, MG
# Processing Record 546 | Shimoda, JP
# Processing Record 547 | Yar-Sale, RU
# Processing Record 548 | Leh, IN
# City not found. Skipping...
# Processing Record 549 | Shache, CN
# City not found. Skipping...
# Processing Record 550 | Trairi, BR
# Processing Record 551 | Santa Rosa, AR
# Processing Record 552 | Puerto Escondido, MX
# Processing Record 553 | Merauke, ID
# Processing Record 554 | San Cristobal, EC
# Processing Record 555 | Manta, RO
# Processing Record 556 | Udachnyy, RU
# Processing Record 557 | Tagusao, PH
# Processing Record 558 | Edson, CA
# Processing Record 559 | Samarai, PG
# Processing Record 560 | San Rafael, AR
# Processing Record 561 | Gaspe, CA
# Processing Record 562 | Puerto Quijarro, BO
# Processing Record 563 | Thinadhoo, MV
# Processing Record 564 | Nelson Bay, AU
# Processing Record 565 | Dhidhdhoo, MV
# Processing Record 566 | Barcelos, PT
# City not found. Skipping...
# Processing Record 567 | Amahai, ID
# Processing Record 568 | Port Augusta, AU
# City not found. Skipping...
# Processing Record 569 | Nioro, GM
# Processing Record 570 | Mezhdurechensk, RU
# City not found. Skipping...
# Processing Record 571 | Matara, PE
# Processing Record 572 | Lishu, CN
# Processing Record 573 | Kulykiv, UA
# Processing Record 574 | Aranos, NA
# Processing Record 575 | Impfondo, CD
# Processing Record 576 | Along, IN
# City not found. Skipping...
# Processing Record 577 | Iralaya, HN
# Processing Record 578 | Avera, US
# Processing Record 579 | Brigham City, US
# City not found. Skipping...
# Processing Record 580 | Fredonia, CO
# Processing Record 581 | Jishou, CN
# Processing Record 582 | Peking, DE
# City not found. Skipping...
# Processing Record 583 | Kazachinskoye, RU
# Processing Record 584 | Hinton, CA
# Processing Record 585 | Lake Charles, US
# Processing Record 586 | Buala, SB
# City not found. Skipping...
# Processing Record 587 | Clinton, US
# Processing Record 588 | Alvinopolis, BR
# Processing Record 589 | Ballina, IE
# Processing Record 590 | Portobelo, PA
# Processing Record 591 | Cap Malheureux, MU
# Processing Record 592 | Narita, JP
# Processing Record 593 | Praya, ID
# Processing Record 594 | Noshiro, JP
# Processing Record 595 | Dabola, GN
# Processing Record 596 | Kanniyakumari, IN
# Processing Record 597 | Akoupe, CI
# Processing Record 598 | Yacuiba, AR
# Processing Record 599 | Pierre, US
# Processing Record 600 | Salinas, US
# Processing Record 601 | Zambezi, ZM
# Processing Record 602 | Qarchi Gak, AF
# Processing Record 603 | Yaguajay, CU
# Processing Record 604 | Bitkine, TD
# Processing Record 605 | Nizhniy Kuranakh, RU
# Processing Record 606 | Pindiga, NG
# Processing Record 607 | Cumana, VE
# Processing Record 608 | Yumen, CN
# Processing Record 609 | Kirakira, SB
# Processing Record 610 | Qasigiannguit, GL
# Processing Record 611 | Lindi, TZ
# Processing Record 612 | Yuli, NG
# Processing Record 613 | Cacu, BR
# City not found. Skipping...
# Processing Record 614 | Kholm-Zhirkovskiy, RU
# Processing Record 615 | Gorontalo, ID
# Processing Record 616 | Biak, ID
# Processing Record 617 | Riachao, BR
# Processing Record 618 | Shangrao, CN
# Processing Record 619 | Nouakchott, MR
# Processing Record 620 | Mutoko, ZW
# Processing Record 621 | Ugoofaaru, MV
# Processing Record 622 | Belaya Gora, RU
# Processing Record 623 | Galveston, US
# Processing Record 624 | Itamaraju, BR
# Processing Record 625 | Santa Isabel, CO
# Processing Record 626 | Porciuncula, BR
# Processing Record 627 | Kouango, CF
# Processing Record 628 | Alencon, FR
# Processing Record 629 | Boende, CD
# Processing Record 630 | Kulu, CD
# Processing Record 631 | Planadas, CO
# Processing Record 632 | Nerchinskiy Zavod, RU
# Processing Record 633 | Tabory, PL
# Processing Record 634 | Bojnurd, IR
# Processing Record 635 | Toucheng, TW
# Processing Record 636 | Baghdad, IQ
# Processing Record 637 | Kamiiso, JP
# Processing Record 638 | Cururupu, BR
# City not found. Skipping...
# Processing Record 639 | Pingliang, CN
# Processing Record 640 | Suba, CN
# Processing Record 641 | Ndioum, SN
# City not found. Skipping...
# Processing Record 642 | Miles City, US
# Processing Record 643 | Ulaanbaatar, MN
# Processing Record 644 | Porbandar, IN
# Processing Record 645 | Dumas, IN
# Processing Record 646 | Tecoanapa, MX
# Processing Record 647 | Ouadda, CF
# Processing Record 648 | Mount Pleasant, US
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 649 | Puro, PH
# City not found. Skipping...
# Processing Record 650 | Hat Yai, TH
# Processing Record 651 | Bang Saphan, TH
# Processing Record 652 | Chapais, CA
# Processing Record 653 | Lakatoro, VU
# City not found. Skipping...
# Processing Record 654 | Makakilo City, US
# City not found. Skipping...
# Processing Record 655 | Havre-Saint-Pierre, CA
# City not found. Skipping...
# Processing Record 656 | Sakaiminato, JP
# Processing Record 657 | Sibu, MY
# Processing Record 658 | Klaebu, NO
# Processing Record 659 | Griffith, AU
# City not found. Skipping...
# Processing Record 660 | Coquimbo, CL
# Processing Record 661 | Choix, MX
# Processing Record 662 | Bajah, YE
# Processing Record 663 | Megion, RU
# Processing Record 664 | Bam, IR
# City not found. Skipping...
# Processing Record 665 | Cassilandia, BR
# Processing Record 666 | Bridlington, GB
# Processing Record 667 | Camotan, GT
# Processing Record 668 | Santa Cruz, US
# City not found. Skipping...
# Processing Record 669 | Hualmay, PE
# --------------------------------
# Data Retrieval Complete
# --------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Organizing the relevant city weather information into a DF using the lists generated earlier
city_weather_df = pd.DataFrame({"City": city_ls,
                                "Country": country_ls,
                                "Lat": lat_ls,
                                "Lng": lng_ls,
                                "Date": date_ls,
                                "Humidity": humidity_ls,
                                "Cloudiness": cloudy_ls,
                                "Max Temp (Celsius)": max_temp_c_ls,
                                "Wind Speed (km/hr)": wind_ls
                               })

# Export city data to csv
city_weather_df.to_csv('city_weather.csv', index=False)

city_weather_df.count()
# Out:
# City                  669
# Country               669
# Lat                   669
# Lng                   669
# Date                  669
# Humidity              669
# Cloudiness            669
# Max Temp (Celsius)    669
# Wind Speed (km/hr)    669
# dtype: int64

# %%
city_weather_df = pd.read_csv('city_weather.csv')

city_weather_df.head(10)
# Out:
#              City Country    Lat     Lng        Date  Humidity  Cloudiness  \
# 0      Nikolskoye      RU  59.70   30.79  1553719507        63           0
# 1  Saint-Philippe      CA  45.36  -73.48  1553719554        35           1
# 2           Saiha      IN  22.49   92.98  1553719558        91           8
# 3       Fatehabad      IN  27.03   78.30  1553719558        56           0
# 4         Talnakh      RU  69.49   88.39  1553719559        93          88
# 5        Hermanus      ZA -34.42   19.24  1553718677        91          48
# 6    Jashpurnagar      IN  22.88   84.14  1553719559        64           0
# 7         Kavieng      PG  -2.57  150.80  1553719559       100          12
# 8          Eureka      US  40.80 -124.16  1553719514        72          40
# 9             Vao      EE  59.10   26.19  1553719560        81          32
#
#    Max Temp (Celsius)  Wind Speed (km/hr)
# 0               -3.00                2.00
# 1                7.78                5.10
# 2               15.45                0.70
# 3               19.30                1.10
# 4               -1.65                8.15
# 5               18.89                0.85
# 6               14.60                1.80
# 7               28.70                3.65
# 8               15.56                6.70
# 9               -4.45                2.65

# %%
# Getting the Date from the data for my sick charts
unix_avg = round(sum(date_ls)/len(date_ls))

local_time = datetime.fromtimestamp(unix_avg)
pretty_local_time = local_time.strftime("%d-%m-%Y")
pretty_local_time
# Out:
# '27-03-2019'

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
x_city_lat = city_weather_df['Lat']

plt.scatter(x_city_lat, city_weather_df['Max Temp (Celsius)'], edgecolors='black', alpha='0.75', color='r')
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (Celsius)')
plt.title(f"City Latitude vs. Max Temp ({pretty_local_time})");

plt.savefig('temp_v_lat.png')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(x_city_lat, city_weather_df['Humidity'], edgecolors='black', alpha='0.5', color = 'blue')
plt.grid()
plt.ylim(0,103)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f"City Latitude vs. Humidity ({pretty_local_time})");

plt.savefig('humid_v_lat.png')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(x_city_lat, city_weather_df['Cloudiness'], edgecolors='black', alpha='0.75', color = 'SkyBlue')
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f"City Latitude vs. Cloudiness ({pretty_local_time})");

plt.savefig('cloudy_v_lat.png')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(x_city_lat, city_weather_df['Wind Speed (km/hr)'], edgecolors='black', alpha='0.5', color = 'gold')
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (km/hr)')
plt.title(f"City Latitude vs. Wind Speed ({pretty_local_time})");

plt.savefig('wind_v_lat.png')
